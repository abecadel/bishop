# %%
# %matplotlib nbagg

import matplotlib.pyplot as plt
import numpy as np
import math

# %%
x = np.linspace(0, 1, 100)
y = np.array([math.sin(2*math.pi*y) for y in x])

# %%
plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,...">

# %%
y = y + np.random.normal(0, 0.1, 100)

# %%
plt.plot(x, y)
